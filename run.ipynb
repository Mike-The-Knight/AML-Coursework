# %%
# !nvidia-smi
# Out:
# Mon Apr 15 11:18:47 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 552.12                 Driver Version: 552.12         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080      WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   63C    P8             13W /  150W |     487MiB /   8192MiB |      6%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Mon_Apr__3_17:36:15_Pacific_Daylight_Time_2023
# Cuda compilation tools, release 12.1, V12.1.105
# Build cuda_12.1.r12.1/compiler.32688072_0

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121, https://pypi.ngc.nvidia.com
# ...

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA is available:", torch.cuda.is_available())
print("Number of CUDA devices:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.1.0.dev20230519+cu121
# CUDA is available: True
# Number of CUDA devices: 1

# %%
# !pip install ultralytics

# %% [markdown]
# ### Dataset preparation

# %%
# !python dataset-image-setup.py

# %%
# !python dataset-labels-setup.py

# %%
# !python dataset-split-setup.py

# %%
# !python dataset-visualisation.py

# %% [markdown]
# ### Nano YOLO Model

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(data='yaml/aircraft.yaml', epochs=3, batch=16, imgsz=640, exist_ok=True, device='cuda:0', workers=2, optimizer='SGD', lr0=0.001, warmup_epochs=0, name='aircraft-n')
# Out:
# New https://pypi.org/project/ultralytics/8.2.12 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.10.11 torch-2.1.0.dev20230519+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 8192MiB)
# ...

# %% [markdown]
# ### Medium YOLO Model

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

results = model.train(data='yaml/aircraft.yaml', epochs=3, batch=16, imgsz=640, exist_ok=True, device='cuda:0', workers=2, optimizer='SGD', lr0=0.001, warmup_epochs=0, name='aircraft-m')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:01<00:00, 31.7MB/s]
# New https://pypi.org/project/ultralytics/8.2.12 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.10.11 torch-2.1.0.dev20230519+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 8192MiB)
# ...

# %% [markdown]
# ### Large YOLO Model

# %%
from ultralytics import YOLO

model = YOLO('yolov8l.pt')

results = model.train(data='yaml/aircraft.yaml', epochs=3, batch=16, imgsz=640, exist_ok=True, device='cuda:0', workers=2, optimizer='SGD', lr0=0.001, warmup_epochs=0, name='aircraft-l')
# Out:
# New https://pypi.org/project/ultralytics/8.2.12 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.10.11 torch-2.1.0.dev20230519+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 8192MiB)
# ...

# %% [markdown]
# ### Full experiment

# %%
from ultralytics import YOLO

model = YOLO('yolov8l.pt')

results = model.train(data='yaml/aircraft.yaml', epochs=10, batch=16, imgsz=640, exist_ok=True, device='cuda:0', workers=2, optimizer='SGD', warmup_epochs=2, name='aircraft-full')
# Out:
# New https://pypi.org/project/ultralytics/8.2.13 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.10.11 torch-2.1.0.dev20230519+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 8192MiB)
# ...
